# %%
import pandas as pd
from google.colab import drive; drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **PATHs**

# %%
MAIN_PATH = "./sentiment_analyzing"
DATA_PATH =  "./sentiment_analyzing/data"
MODEL_PATH = "./sentiment_analyzing/training_results/models"
LOGGING_PATH = "./sentiment_analyzing/training_results/loggings"
CHECK_PATH = "./sentiment_analyzing/training_results/models/checkpoints"

# %%
CSV_DATA_FILES = {
    "tass_2020_comments": "./sentiment_analyzing/data/datasets/tass_2020_sentiment.csv",
    "tass_clean": "./sentiment_analyzing/data/datasets/tass_clean.csv",
}

TXT_DATA_FILES = {
    "articles_contractions": "./sentiment_analyzing/data/linguistic_features/articles_contractions.txt",
    "prepositions": "./sentiment_analyzing/data/linguistic_features/prepositions.txt",
    "pronouns": "./sentiment_analyzing/data/linguistic_features/pronouns.txt",
    "human_names": "./sentiment_analyzing/data/linguistic_features/entity_human_names.txt",
    "mundi": "./sentiment_analyzing/data/linguistic_features/entity_mundi.txt",
}

# %% [markdown]
# # **Importación de datos**

# %%
def get_txt_data(path_dict):
  out = []
  for k, v in path_dict.items():
    with open(v) as f:
      k = [line.rstrip() for line in f]
      out.append(k)
  return out

# %%
def get_csv_data(path_dict):
  out = []
  for k, v in path_dict.items():
      k = pd.read_csv(v, index_col=[0])
      out.append(k)
  return out

# %%
articles_contractions, prepositions, pronouns, human_names, mundi = get_txt_data(TXT_DATA_FILES)
human_names = set(human_names)
mundi = set(mundi)

# %% [markdown]
# # **Constantes**

# %%
RANDOM_SEED = 0

STOP_WORDS = articles_contractions + pronouns + prepositions

NAMED_ENTITES = set.union(human_names, mundi)

TASS_2020_COMMENTS, TASS_CLEAN = get_csv_data(CSV_DATA_FILES)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
